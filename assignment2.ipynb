# %%
import pandas as pd
Costomer = pd.read_csv("customer_data.csv")
# 1 - last 5
print(Costomer.tail(5))

# 2 - Header of column
print(Costomer.columns)

# 3 - Delete Column
Costomer.drop("Surname",axis=1,inplace=True)
print(Costomer.head(1))

# 4 - Create New DB Age Gender Balance field
newDb = Costomer[["Age","Balance","Gender"]]
print(newDb)

# 5 - Count number of missing values
missingValues =  Costomer.isnull().sum()
print(missingValues)

# 6 - Ballance between 8000 10000
conditionOutput = Costomer[Costomer["Balance"].between(8000,10000)]
print(conditionOutput)

# 7 - Count the sum of each category 
Costomer['Geography'].value_counts()
# Out:
#    CustomerId   Surname Geography  Gender  Age  Balance  Tenure  \
# 5    15574012       Chu    France    Male   44     6500       8
# 6    15592531  Bartlett   Germany  Female   50     9800       7
# 7    15656148    Obinna   Germany    Male   29     7200       4
# 8    15792365        He    France  Female   44     5800       6
# 9    15592389        H?     Spain  Female   27        0       3
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 5            2.0          1               0         10062.80
# 6            2.0          1               1        119346.88
# 7            2.0          1               1         74940.50
# 8            1.0          1               0         71725.73
# 9            1.0          1               0             0.00
# Index(['CustomerId', 'Surname', 'Geography', 'Gender', 'Age', 'Balance',
#        'Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary'],
#       dtype='object')
#    CustomerId Geography  Gender  Age  Balance  Tenure  NumOfProducts  \
# 0    15634602    France  Female   42        0       2            1.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
#    Age  Balance  Gender
# 0   42        0  Female
# 1   41    12000    Male
# 2   41    25000  Female
# 3   39    15000    Male
# 4   43    18000  Female
# 5   44     6500    Male
# 6   50     9800  Female
# 7   29     7200    Male
# 8   44     5800  Female
# 9   27        0  Female
# CustomerId         0
# Geography          0
# Gender             0
# Age                0
# Balance            0
# Tenure             0
# NumOfProducts      1
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64
#    CustomerId Geography  Gender  Age  Balance  Tenure  NumOfProducts  \
# 6    15592531   Germany  Female   50     9800       7            2.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 6          1               1        119346.88
# Geography
# France     5
# Spain      3
# Germany    2
# Name: count, dtype: int64
