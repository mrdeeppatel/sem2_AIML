# %%
import seaborn as sns 
from matplotlib import pyplot as plt
import pandas as pd
params = sns.axes_style()
print(params)
# Out:
# {'axes.facecolor': 'white', 'axes.edgecolor': 'black', 'axes.grid': False, 'axes.axisbelow': 'line', 'axes.labelcolor': 'black', 'figure.facecolor': (1, 1, 1, 0), 'grid.color': '#b0b0b0', 'grid.linestyle': '-', 'text.color': 'black', 'xtick.color': 'black', 'ytick.color': 'black', 'xtick.direction': 'out', 'ytick.direction': 'out', 'lines.solid_capstyle': <CapStyle.projecting: 'projecting'>, 'patch.edgecolor': 'black', 'patch.force_edgecolor': False, 'image.cmap': 'viridis', 'font.family': ['sans-serif'], 'font.sans-serif': ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif'], 'xtick.bottom': True, 'xtick.top': False, 'ytick.left': True, 'ytick.right': False, 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True}

# %%
df1 = sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
# sns.set_style("darkgrid",{'grid.color':"0.8"})


sns.set_context("poster")

# sns.set_context("notebook")

plt.show()

# %%
df2 = sns.load_dataset('tips')
plt.scatter('total_bill','tip',data=df2)

sns.relplot(data=df2,x="total_bill",y="tip")

# %%
# sns.relplot(data=df2,x="total_bill",y="tip",hue='time',col='day',col_wrap=2)
# sns.relplot(data=df2,x="total_bill",y="tip",hue='time',col='day',col_wrap=3)
# sns.relplot(data=df2,x="total_bill",y="tip",hue='time',col='day',col_wrap=1)
sns.relplot(data=df2,x="total_bill",y="tip",hue='time',col='day',col_wrap=4)

# %%
sns.relplot(data=df2,x="size",y="tip",kind="line",ci=None)
# Out:
# /home/student/.local/lib/python3.9/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 sns.relplot(data=df2,x="size",y="tip",kind="line",ci=None)
#
# File ~/.local/lib/python3.9/site-packages/seaborn/relational.py:838, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     829 g = FacetGrid(
#     830     data=full_data.dropna(axis=1, how="all"),
#     831     **grid_kws,
#    (...)
#     834     **facet_kws
#     835 )
#     837 # Draw the plot
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df2 = sns.load_dataset('tips')

# Create a line plot
sns.lineplot(data=df2, x='size', y='tip')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       5 df2 = sns.load_dataset('tips')
#       7 # Create a line plot
# ----> 8 sns.lineplot(data=df2, x='size', y='tip')
#       9 plt.show()
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
data = sns.load_dataset("tips")
print(data)

sns.pointplot(x="day",y="tip",data=data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...

# %%
sns.pointplot(x="day",y="tip",data=data,hue="smoker",palette="Accent")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="totel_bill",y='tip',data=data,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 sns.jointplot(x="totel_bill",y='tip',data=data)
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:2230, in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
# ...

# %%
sns.boxplot(x="day",y="total_bill",data=data)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
flights = sns.load_dataset("flights")

flits_pivot= flights.pivot(
    index="month",
    columns="year",
    values="passengers"
)
print(flits_pivot)
sns.heatmap(flits_pivot,fmt="d")
plt.show()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
car_crashes = sns.load_dataset("car_crashes")
print(car_crashes)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
car_crashes = sns.load_dataset("car_crashes")

# Display the first few rows
print(car_crashes.head())

# Select only numeric columns
numeric_cols = car_crashes.select_dtypes(include=['number'])

print(numeric_cols)
# Calculate the correlation matrix
corr = numeric_cols.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, fmt=".2f")
plt.title("Correlation Heatmap of Car Crashes Dataset")
plt.show()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df2 = sns.load_dataset('tips')

# Create a pairplot with hue based on 'day'
sns.pairplot(df2, hue="day")

# Show the plot
plt.show()
# Out:
# /home/student/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/student/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
tips = sns.load_dataset("tips")
print(tips)

# Calculate the average total bill for each day
avg_of_each_day = tips.groupby("day")["total_bill"].mean().reset_index()

# Plot the average total bill per day
sns.barplot(x="day", y="total_bill", data=avg_of_each_day)
plt.show()

# Print the DataFrame with averages
print(avg_of_each_day)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...

# %%
prnguins = sns.load_dataset("penguins")

sns.boxplot(x='species',y='body_mass_g',data=prnguins)
plt.show()
